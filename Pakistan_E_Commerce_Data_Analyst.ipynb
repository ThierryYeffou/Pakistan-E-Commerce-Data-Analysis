# %% [markdown]
# <a href="https://colab.research.google.com/github/ThierryYeffou/Pakistan-E-Commerce-Data-Analysis/blob/main/Pakistan_E_Commerce_Data_Analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import des bibliothèque
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Nettoyage des données**

# %%
#Collection : dataset
path = "/content/data_set"
file_data = [file for file in os.listdir(path)]
#print(file_data)
for file in file_data:
  print(file)
# Out:
# Pakistan Largest Ecommerce Dataset.csv

# %%
#Creons la base de données :
all_data = pd.DataFrame()
for file in file_data :
  all_data = pd.read_csv(path+'/'+file)
all_data
# Out:
# <ipython-input-21-15512b8b26d5>:4: DtypeWarning: Columns (1,2,3,7,8,9,11,12,13,14,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_data = pd.read_csv(path+'/'+file)
#           item_id          status created_at  \
# 0        211131.0        complete   7/1/2016
# 1        211133.0        canceled   7/1/2016
# 2        211134.0        canceled   7/1/2016
# 3        211135.0        complete   7/1/2016
# 4        211136.0  order_refunded   7/1/2016
# ...           ...             ...        ...
# 1048570       NaN             NaN        NaN
# 1048571       NaN             NaN        NaN
# 1048572       NaN             NaN        NaN
# 1048573       NaN             NaN        NaN
# 1048574       NaN             NaN        NaN
#
#                                                        sku   price  \
# 0                                        kreations_YI 06-L  1950.0
# 1        kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0
# ...

# %%
#Observons nos données en profondeur :
#all_data.dtypes
#all_data.shape
#all_data.head()
#all_data.columns
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447349 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
# ...

# %%
#Comptons le nombre de valeur null
all_data.isnull().sum()
# Out:
# item_id                   464051
# status                    464066
# created_at                464051
# sku                       464071
# price                     464051
# qty_ordered               464051
# grand_total               464051
# increment_id              464051
# category_name_1           464215
# sales_commission_code     601226
# discount_amount           464051
# payment_method            464051
# Working Date              464051
# BI Status                 464051
#  MV                       464051
# Year                      464051
# Month                     464051
# Customer Since            464062
# M-Y                       464051
# FY                        464051
# Customer ID               464062
# Unnamed: 21              1048575
# Unnamed: 22              1048575
# Unnamed: 23              1048575
# Unnamed: 24              1048575
# Unnamed: 25              1048575
# dtype: int64

# %%
#Suppression des valeurs manquantes
all_data = all_data.dropna(how="all")
all_data
# Out:
#          item_id          status created_at  \
# 0       211131.0        complete   7/1/2016
# 1       211133.0        canceled   7/1/2016
# 2       211134.0        canceled   7/1/2016
# 3       211135.0        complete   7/1/2016
# 4       211136.0  order_refunded   7/1/2016
# ...          ...             ...        ...
# 584519  905204.0             cod  8/28/2018
# 584520  905205.0      processing  8/28/2018
# 584521  905206.0      processing  8/28/2018
# 584522  905207.0      processing  8/28/2018
# 584523  905208.0      processing  8/28/2018
#
#                                                       sku     price  \
# 0                                       kreations_YI 06-L    1950.0
# 1       kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...     240.0
# 2                                      Ego_UP0017-999-MR0    2450.0
# 3                                          kcc_krone deal     360.0
# 4                                             BK7010400AG     555.0
# ...

# %%
all_data.isnull().sum()
# Out:
# item_id                       0
# status                       15
# created_at                    0
# sku                          20
# price                         0
# qty_ordered                   0
# grand_total                   0
# increment_id                  0
# category_name_1             164
# sales_commission_code    137175
# discount_amount               0
# payment_method                0
# Working Date                  0
# BI Status                     0
#  MV                           0
# Year                          0
# Month                         0
# Customer Since               11
# M-Y                           0
# FY                            0
# Customer ID                  11
# Unnamed: 21              584524
# Unnamed: 22              584524
# Unnamed: 23              584524
# Unnamed: 24              584524
# Unnamed: 25              584524
# dtype: int64

# %%
#Corrigeons l'espace sur la colonne MV :
all_data.rename(columns={' MV ':'MV'}, inplace=True)
all_data.columns
# Out:
# <ipython-input-26-3ebd17f172fa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data.rename(columns={' MV ':'MV'}, inplace=True)
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', 'MV', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
all_data.dtypes
# Out:
# item_id                  float64
# status                    object
# created_at                object
# sku                       object
# price                    float64
# qty_ordered              float64
# grand_total              float64
# increment_id              object
# category_name_1           object
# sales_commission_code     object
# discount_amount          float64
# payment_method            object
# Working Date              object
# BI Status                 object
# MV                        object
# Year                     float64
# Month                    float64
# Customer Since            object
# M-Y                       object
# FY                        object
# Customer ID              float64
# Unnamed: 21              float64
# Unnamed: 22              float64
# Unnamed: 23              float64
# Unnamed: 24              float64
# Unnamed: 25              float64
# dtype: object

# %%
#Conversion de types pour quelques colonnes
all_data['item_id']= all_data['item_id'].astype(int)
all_data['qty_ordered'] = all_data['qty_ordered'].astype(int)
all_data['Year'] = all_data['Year'].astype(int)
all_data['Month'] = all_data['Month'].astype(int)
all_data['Customer ID'] = all_data['Customer ID'].astype(str)
# Out:
# <ipython-input-28-3f8e47ac0e5f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['item_id']= all_data['item_id'].astype(int)
# <ipython-input-28-3f8e47ac0e5f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['qty_ordered'] = all_data['qty_ordered'].astype(int)
# <ipython-input-28-3f8e47ac0e5f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Changer la category_name_1 en catégorie
all_data.rename(columns={'category_name_1':'Category'}, inplace=True)
# Out:
# <ipython-input-29-3e4bc63d34fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data.rename(columns={'category_name_1':'Category'}, inplace=True)

# %%
all_data.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'Category', 'sales_commission_code',
#        'discount_amount', 'payment_method', 'Working Date', 'BI Status', 'MV',
#        'Year', 'Month', 'Customer Since', 'M-Y', 'FY', 'Customer ID',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='object')

# %% [markdown]
# # **Analysons les 10 catégories les plus vendues et visualisons**

# %%
all_data.groupby('Category')['item_id'].count()
# Out:
# Category
# Appliances             52413
# Beauty & Grooming      41496
# Books                   1870
# Computing              15933
# Entertainment          26326
# Health & Sports        17502
# Home & Living          26504
# Kids & Baby            16494
# Men's Fashion          92221
# Mobiles & Tablets     115710
# Others                 29218
# School & Education      3478
# Soghaat                34011
# Superstore             43613
# Women's Fashion        59721
# \N                      7850
# Name: item_id, dtype: int64

# %%
all_data.groupby('Category')['item_id'].agg(['count'])
# Out:
#                      count
# Category
# Appliances           52413
# Beauty & Grooming    41496
# Books                 1870
# Computing            15933
# Entertainment        26326
# Health & Sports      17502
# Home & Living        26504
# Kids & Baby          16494
# Men's Fashion        92221
# Mobiles & Tablets   115710
# Others               29218
# School & Education    3478
# Soghaat              34011
# Superstore           43613
# Women's Fashion      59721
# \N                    7850

# %%
plt.bar(all_data.groupby('Category')['grand_total'].sum().index, all_data.groupby('Category')['grand_total'].sum())
plt.xticks(rotation='vertical')
plt.ylabel('Total Ventes')
plt.xlabel('Categories')
plt.show()
